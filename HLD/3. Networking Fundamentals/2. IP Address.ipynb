# %% [markdown]
# 1. Every time you visit a website, send an email, or make an API call, your **device uses an IP address to identify itself.**
#
# 2. This address ensures that the data you request finds its way back to you, and the data you send reaches its intended destination.

# %% [markdown]
# **1. The Internet Protocol (IP) is the set of rules that governs this addressing system.**
#
# **2. It operates at Layer 3 (the Network Layer) of the OSI Model, where its primary job is to provide logical addressing and route packets of data from a source device to a destination device across one or more networks.**

# %% [markdown]
# ## 1. What Is an IP Address?
#
# 1. An IP address is a unique numerical label assigned to each device connected to a network that uses the Internet Protocol for communication. Think of it as a phone number for your computer or a mailing address for your laptop.
#
# 2. It serves two primary functions:
#
#     1. **Identification**: It uniquely identifies a device (or more accurately, a network interface) on the network. This tells other devices who is sending or receiving information.
#     2. **Location Addressing**: It specifies the location of the device in the network, providing a path for data to be delivered.

# %% [markdown]
# ## 2. IP Address Structure
#
# 1. An IP address isn't just a random number; it has a clear structure that is split into two main parts:
#
#     1. **Network ID**: This part of the address identifies the specific network the device is on. All devices on the same local network share the same Network ID.
#     2. **Host ID**: This part of the address identifies a specific device (like a computer, server, or smartphone) within that network.
#     3. For example, in the common IPv4 address 192.168.1.10 with a standard subnet mask, the breakdown is:
#
#             Network ID: 192.168.1
#
#             Host ID: 10
#
# 2. Routers primarily look at the Network ID. They don't need to know about every single device in the world, only which network a packet is destined for. They use this information to forward the packet to the next router closer to the destination network.

# %% [markdown]
# ## 3. IPv4: The Classic Address Format
#
# 1. Internet Protocol version 4 (IPv4) is the original and most widely used IP addressing system.
#
# 2. It's a **32-bit address**, meaning there are 2^32 (approximately 4.3 billion) possible unique addresses.
#
#     1. Each IP address = 32 bits = 4 bytes (since 1 byte = 8 bits).
#
#     2. It’s usually written in dotted decimal notation like this:
#             192.168.1.10
#
#     3. Each part (called an octet) represents 8 bits and can range from 0 to 255.
#
#     4. Example in Binary
#             Let’s take 192.168.1.10
#        Binary form: 11000000.10101000.00000001.00001010
#
# 3. Format  : It is written as **four numbers separated by dots** (dotted-decimal notation), where **each number is an "octet"** ranging from 0 to 255 (e.g., 172.217.167.78).
#
# 4. Address Classes
#
#     Historically, IPv4 addresses were divided into classes (A, B, C) to define the split between network and host IDs. While this system is now largely replaced by CIDR (see below), it's useful historical context.
#
#     Class A: For very large networks (e.g., 10.0.0.0).
#
#     Class B: For medium-sized networks (e.g., 172.16.0.0).
#
#     Class C: For small networks (e.g., 192.168.1.0).
#
# 5. Limitation : **The biggest issue with IPv4 is address exhaustion. With the explosion of internet-connected devices, the ~4.3 billion addresses have effectively run out.**

# %% [markdown]
# ## 4. IPv6: The Modern Standard
#
# 1. To solve the address exhaustion problem, Internet Protocol version 6 (IPv6) was developed.
#
# 2. It's a 128-bit address, providing a staggering 2^128 (or 340 undecillion) unique addresses. This is enough to assign an IP address to every atom on the surface of the Earth, and still have addresses left over.
#
# 3. Format : It is written as **eight groups of four hexadecimal digits, separated by colons (e.g., 2001:0db8:85a3:0000:0000:8a2e:0370:7334)**. Zeros can be compressed for brevity.
#
# 4. IPv6 isn't just bigger; it's better. It includes several built-in improvements:
#
#     1. **Stateless Address Autoconfiguration (SLAAC)**: Devices can generate their own IP address without needing a DHCP server.
#     2. **No NAT**: The massive address space eliminates the need for Network Address Translation (NAT), simplifying networks.
#     3. **Built-in Security**: **IPsec, a suite of protocols for securing communications**, is a mandatory part of IPv6.
#     4. **Efficient Routing**: Simplified **packet headers allow for faster processing** by routers.

# %% [markdown]
# # 5. Public vs Private IP Addresses
#
# Not all IP addresses are created equal. They are divided into two main categories:
#
# 1. **Public IP Address:** This is a globally unique address that is routable on the internet. Your Internet Service Provider (ISP) assigns one to your router. When you visit a website, your request is sent from your public IP.
#
# 2. **Private IP Address:** This is an address used within a local, private network (like your home Wi-Fi or an office LAN). These addresses are not routable on the internet and are reused in millions of private networks worldwide.
#
# 3. The standard private IP ranges are:
#
#     10.0.0.0 to 10.255.255.255
#     172.16.0.0 to 172.31.255.255
#     192.168.0.0 to 192.168.255.255
#
#     So how do devices with private IPs access the internet?
#
# Through **Network Address Translation (NAT).**
#
# 1. Your home router acts as a NAT gateway.
# 2. It takes requests from devices on your private network, replaces their private source IP with its single public IP, and sends the request to the internet.
# 3. When the response comes back, the router knows which private device to forward it to.

# %% [markdown]
# ## 6. Static vs Dynamic IP Addresses
#
# IP addresses can be assigned in two ways:
#
# 1. **Static IP:** A static IP address is manually configured for a device and does not change. This is essential for servers, printers, and other devices that need to be consistently reachable at the same address. They are reliable but often cost more and require manual management.
#
# 2. **Dynamic IP:** A dynamic IP address is assigned automatically by a DHCP (Dynamic Host Configuration Protocol) server. Most consumer devices (laptops, phones) get dynamic IPs. The address is leased for a period and can change the next time you connect. This is highly efficient for managing large numbers of devices.
#
#
# 3. Example : Turn off DHCP (that’s what assigns dynamic IPs automatically) , in home printer we can use this to keep it fixed that can be changed by router.

# %% [markdown]
# ## 7. Subnetting and CIDR
#
# 1. As networks grow, it's often necessary to divide them into smaller, more manageable segments. This process is called subnetting. It helps improve performance, enhance security, and organize the network logically.
#
# 2. Subnetting involves "borrowing" bits from the Host ID part of an IP address to create more Network IDs. A subnet mask is used to tell devices which part of the address is the network and which is the host.
#
# 3. This is where **CIDR (Classless Inter-Domain Routing)** comes in. CIDR abandoned the old classful system and introduced a more flexible way to define the network portion of an address. CIDR notation uses a slash followed by a number to represent the number of bits in the Network ID.
#
# Example :
#
# 8 bits for hosts → 2^8 = 256 total IPs
# Subtract 2 (network + broadcast) → 254 usable hosts
#
#
# 1. 192.168.1.0/24 means the first 24 bits are the Network ID.
#
#         Subnet Mask: 255.255.255.0
#
#         Hosts: 254
#
# 2. 192.168.1.0/26 means the first 26 bits are the Network ID.
#
#         Subnet Mask: 255.255.255.192
#
#         This splits the /24 network into four smaller subnets, each with 62 hosts.
#
#         (2 ^ 6 = 64 => then subtract 2)
#
# 24 → one big neighborhood with 254 houses (everyone can talk to everyone).
# /26 → same neighborhood divided into 4 smaller gated communities (each 62 houses, isolated from others).

# %% [markdown]
# ## 8. Loopback and Special Addresses
#
# Besides public and private addresses, there are several special-purpose IP addresses:
#
# 1. **Loopback Address:** 127.0.0.1 (IPv4) and ::1 (IPv6). This address, also known as "localhost," always refers to the local device itself. It's used for testing network applications without sending packets out onto the network.
#
#    Usecase : Used by your computer to test its own networking functions without sending data out onto the physical network.
#
#    Example: Suppose you’re developing a web application and running a local web server (like FastAPI or Node.js). You can open your browser and go to: http://127.0.0.1:8000
#    or http://localhost:8000
#
#    Even though you’re using network protocols, all communication happens inside your own machine — it doesn’t leave your computer.
#
# 2. **Broadcast Address:** An address used to send a message to all devices on a local subnet simultaneously (e.g., 192.168.1.255 for the 192.168.1.0/24 network).
#
#     Use Case:
#
#     1. When a computer boots up and doesn’t know the IP of other devices (like a DHCP server), it can broadcast a “Who is the DHCP server?” request.
#
#     2. Every device in the subnet hears this, but only the DHCP server responds.(A DHCP (Dynamic Host Configuration Protocol) server automatically assigns IP addresses and network settings to devices when they join a network.)
#
#
# 3. **Link-local Address:** The 169.254.0.0/16 range. If a device is configured for DHCP but cannot find a DHCP server, it will assign itself an address from this range to communicate on the local network. It allows basic communication with other local devices on the same network (like sharing files or printers).
#
#
#     Example:
#
#     1. You plug two laptops together with an Ethernet cable.
#
#             Laptop A assigns itself 169.254.1.10
#
#             Laptop B assigns itself 169.254.1.20
#
#     Now they can still communicate locally, even without a router or DHCP server.
#
# 4. **Multicast Addresses:** A special block of addresses used for one-to-many communication, where a single packet is sent to a "group" of interested receivers.
#
#     Example:
#
#     1. A video streaming server might send data to multicast group 224.1.1.1.Any devices that want that stream “join” the group.
#     2. So instead of sending 100 copies of the same video to 100 devices, the server sends one copy, and the network delivers it to all group members.
#     3. Use Case:IPTV (Internet TV)
